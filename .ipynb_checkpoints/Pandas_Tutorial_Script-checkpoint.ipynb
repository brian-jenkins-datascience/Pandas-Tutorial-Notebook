# %% [markdown]
# # Import Pandas!

# %% [markdown]
# We start by importing pandas! This package is included with the base installation of Anaconda.
#
# Also let's import numpy.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series and DataFrame Basics

# %% [markdown]
# Now we need some data to manipulate...
#
# Suppose there were 7 guys whose favorite colors and numbers were as given below:

# %% [markdown]
# ## Creating a DataFrame

# %%
names = ['Timmy','Jimmy','Ed','Ned','Fred','Jed','Ted']
colors = ['red','blue','green','red','yellow','orange','blue']
numbers = [100,25,34,7,60,2,55]

# %%
df = pd.DataFrame({'Name': names, 'Color': colors,'Number':numbers})

# %%
df
# Out:
#     Name   Color  Number
# 0  Timmy     red     100
# 1  Jimmy    blue      25
# 2     Ed   green      34
# 3    Ned     red       7
# 4   Fred  yellow      60
# 5    Jed  orange       2
# 6    Ted    blue      55

# %%
df.columns.tolist() #first do without .tolist()
# Out:
# ['Name', 'Color', 'Number']

# %%
df.index.tolist()
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %% [markdown]
# ## Accessing Columns/Rows

# %%
df['Name']
# Out:
# 0    Timmy
# 1    Jimmy
# 2       Ed
# 3      Ned
# 4     Fred
# 5      Jed
# 6      Ted
# Name: Name, dtype: object

# %%
df['Color']
# Out:
# 0       red
# 1      blue
# 2     green
# 3       red
# 4    yellow
# 5    orange
# 6      blue
# Name: Color, dtype: object

# %%
df.loc[1]
# Out:
# Name      Jimmy
# Color      blue
# Number       25
# Name: 1, dtype: object

# %% [markdown]
# ## Selecting Multiple Columns/Rows

# %%
df[['Color','Name']]
# Out:
#     Color   Name
# 0     red  Timmy
# 1    blue  Jimmy
# 2   green     Ed
# 3     red    Ned
# 4  yellow   Fred
# 5  orange    Jed
# 6    blue    Ted

# %%
df.loc[[1,3]]
# Out:
#     Name Color  Number
# 1  Jimmy  blue      25
# 3    Ned   red       7

# %% [markdown]
# ## Selecting the First/Last k Amount of Rows

# %%
df.head(5)
# Out:
#     Name   Color  Number
# 0  Timmy     red     100
# 1  Jimmy    blue      25
# 2     Ed   green      34
# 3    Ned     red       7
# 4   Fred  yellow      60

# %%
df.tail(3)
# Out:
#    Name   Color  Number
# 4  Fred  yellow      60
# 5   Jed  orange       2
# 6   Ted    blue      55

# %% [markdown]
# ## Iterating through rows of a dataframe

# %% [markdown]
# Generally speaking, I'm not a big fan of iterating through dataframes as a solution since dataframes are built for vectorization.
#
#
# However sometimes it's necessary, and we can iterate through the rows of a dataframe as follows:

# %%
df
# Out:
#     Name   Color  Number
# 0  Timmy     red     100
# 1  Jimmy    blue      25
# 2     Ed   green      34
# 3    Ned     red       7
# 4   Fred  yellow      60
# 5    Jed  orange       2
# 6    Ted    blue      55

# %%
for index, row in df.iterrows(): #this outputs 2 things: an index and a pandas Series. We use row.values to extract the row values themselves.
    print(index, end='\t')
    print(row.values)    #first execute without .values to show the difference
# Out:
# 0	['Timmy' 'red' 100]
# 1	['Jimmy' 'blue' 25]
# 2	['Ed' 'green' 34]
# 3	['Ned' 'red' 7]
# 4	['Fred' 'yellow' 60]
# 5	['Jed' 'orange' 2]
# 6	['Ted' 'blue' 55]

# %%
for index, row in df.iterrows():
    print('Index: {}\tName: {}\tFavorite Number: {}'.format(index,row['Name'],row['Number']))
# Out:
# Index: 0	Name: Timmy	Favorite Number: 100
# Index: 1	Name: Jimmy	Favorite Number: 25
# Index: 2	Name: Ed	Favorite Number: 34
# Index: 3	Name: Ned	Favorite Number: 7
# Index: 4	Name: Fred	Favorite Number: 60
# Index: 5	Name: Jed	Favorite Number: 2
# Index: 6	Name: Ted	Favorite Number: 55

# %% [markdown]
# # Manipulating DataFrames

# %% [markdown]
# ## Adding Columns to DataFrame

# %%
df['Age'] = [25,20,19,np.nan,50,23,40]

# %%
df
# Out:
#     Name   Color  Number   Age
# 0  Timmy     red     100  25.0
# 1  Jimmy    blue      25  20.0
# 2     Ed   green      34  19.0
# 3    Ned     red       7   NaN
# 4   Fred  yellow      60  50.0
# 5    Jed  orange       2  23.0
# 6    Ted    blue      55  40.0

# %% [markdown]
# ## Adding Rows to DataFrame

# %%
df.loc[7] = ['Bob',np.nan,80,39]

# %%
df
# Out:
#     Name   Color  Number   Age
# 0  Timmy     red     100  25.0
# 1  Jimmy    blue      25  20.0
# 2     Ed   green      34  19.0
# 3    Ned     red       7   NaN
# 4   Fred  yellow      60  50.0
# 5    Jed  orange       2  23.0
# 6    Ted    blue      55  40.0
# 7    Bob     NaN      80  39.0

# %% [markdown]
# ## Concatenating Two DataFrames

# %%
df_new = pd.DataFrame({'Name': ['Steve','Julius','Dwight'], 'Color': ['violet','indigo','pink'],'Number': [392,40,10],'Age': [24,42,33]})

# %%
pd.concat([df,df_new]) #notice the indices
# Out:
#      Name   Color  Number   Age
# 0   Timmy     red     100  25.0
# 1   Jimmy    blue      25  20.0
# 2      Ed   green      34  19.0
# 3     Ned     red       7   NaN
# 4    Fred  yellow      60  50.0
# 5     Jed  orange       2  23.0
# 6     Ted    blue      55  40.0
# 7     Bob     NaN      80  39.0
# 0   Steve  violet     392  24.0
# 1  Julius  indigo      40  42.0
# 2  Dwight    pink      10  33.0

# %%
pd.concat([df,df_new]).loc[0].iloc[1] #With these indices, obtaining the row containing Steve via indices is sloppy, isn't it?
# Out:
# Name       Steve
# Color     violet
# Number       392
# Age         24.0
# Name: 0, dtype: object

# %%
pd.concat([df,df_new],ignore_index=True) #much more intuitive now to simply use .loc[8]
# Out:
#       Name   Color  Number   Age
# 0    Timmy     red     100  25.0
# 1    Jimmy    blue      25  20.0
# 2       Ed   green      34  19.0
# 3      Ned     red       7   NaN
# 4     Fred  yellow      60  50.0
# 5      Jed  orange       2  23.0
# 6      Ted    blue      55  40.0
# 7      Bob     NaN      80  39.0
# 8    Steve  violet     392  24.0
# 9   Julius  indigo      40  42.0
# 10  Dwight    pink      10  33.0

# %%
pd.concat([df,df_new],ignore_index=True).loc[8]
# Out:
# Name       Steve
# Color     violet
# Number       392
# Age         24.0
# Name: 8, dtype: object

# %% [markdown]
# ## Replacing data within a DataFrame

# %% [markdown]
# Whole entries

# %%
df.replace('blue','purple') # replaces whole entries in the dataframe
# Out:
#     Name   Color  Number   Age
# 0  Timmy     red     100  25.0
# 1  Jimmy  purple      25  20.0
# 2     Ed   green      34  19.0
# 3    Ned     red       7   NaN
# 4   Fred  yellow      60  50.0
# 5    Jed  orange       2  23.0
# 6    Ted  purple      55  40.0
# 7    Bob     NaN      80  39.0

# %% [markdown]
# Substrings

# %%
df.replace('immy','imbo',regex = True) #replaces string patterns within each word
# Out:
#     Name   Color  Number   Age
# 0  Timbo     red     100  25.0
# 1  Jimbo    blue      25  20.0
# 2     Ed   green      34  19.0
# 3    Ned     red       7   NaN
# 4   Fred  yellow      60  50.0
# 5    Jed  orange       2  23.0
# 6    Ted    blue      55  40.0
# 7    Bob     NaN      80  39.0

# %% [markdown]
# ## Filling in Missing Data Values

# %%
df.fillna(0)
# Out:
#     Name   Color  Number   Age
# 0  Timmy     red     100  25.0
# 1  Jimmy    blue      25  20.0
# 2     Ed   green      34  19.0
# 3    Ned     red       7   0.0
# 4   Fred  yellow      60  50.0
# 5    Jed  orange       2  23.0
# 6    Ted    blue      55  40.0
# 7    Bob       0      80  39.0

# %%
df['Age'].mean()
# Out:
# 30.857142857142858

# %%
df = df.fillna({'Color':'none','Age':df['Age'].mean()})

# %%
df
# Out:
#     Name   Color  Number        Age
# 0  Timmy     red     100  25.000000
# 1  Jimmy    blue      25  20.000000
# 2     Ed   green      34  19.000000
# 3    Ned     red       7  30.857143
# 4   Fred  yellow      60  50.000000
# 5    Jed  orange       2  23.000000
# 6    Ted    blue      55  40.000000
# 7    Bob    none      80  39.000000

# %%
df['Age'].round()
# Out:
# 0    25.0
# 1    20.0
# 2    19.0
# 3    31.0
# 4    50.0
# 5    23.0
# 6    40.0
# 7    39.0
# Name: Age, dtype: float64

# %%
df['Age'] = df['Age'].round().astype(int)

# %%
df
# Out:
#     Name   Color  Number  Age
# 0  Timmy     red     100   25
# 1  Jimmy    blue      25   20
# 2     Ed   green      34   19
# 3    Ned     red       7   31
# 4   Fred  yellow      60   50
# 5    Jed  orange       2   23
# 6    Ted    blue      55   40
# 7    Bob    none      80   39

# %% [markdown]
# ## Filtering DataFrames

# %%
df
# Out:
#     Name   Color  Number  Age
# 0  Timmy     red     100   25
# 1  Jimmy    blue      25   20
# 2     Ed   green      34   19
# 3    Ned     red       7   31
# 4   Fred  yellow      60   50
# 5    Jed  orange       2   23
# 6    Ted    blue      55   40
# 7    Bob    none      80   39

# %%
df[df['Number'] < df['Age']]
# Out:
#   Name   Color  Number  Age
# 3  Ned     red       7   31
# 5  Jed  orange       2   23

# %% [markdown]
# ### .str accessor within dataframes

# %%
df[df['Name'].str.contains('ed')] #rows such that the 'Name' field contains the string 'ed'
# Out:
#    Name   Color  Number  Age
# 3   Ned     red       7   31
# 4  Fred  yellow      60   50
# 5   Jed  orange       2   23
# 6   Ted    blue      55   40

# %%
df[df['Color'].str.count('l') >= 1] #rows such that the 'Color' field contains at least 1 'l'
# Out:
#     Name   Color  Number  Age
# 1  Jimmy    blue      25   20
# 4   Fred  yellow      60   50
# 6    Ted    blue      55   40

# %% [markdown]
# ### Multiple conditions

# %% [markdown]
# Whenever you have multiple conditions in a dataframe query, you need to ensure that each condition is surrounded by parentheses. This is due to how the order of operations works within pandas.

# %%
df[(df['Number'] > 20) & (df['Age'] > 30)]
# Out:
#    Name   Color  Number  Age
# 4  Fred  yellow      60   50
# 6   Ted    blue      55   40
# 7   Bob    none      80   39

# %%
# & = 'AND'
# | = 'OR'

df[(df['Number'] > 20) & (df['Age'] > 30) | (df['Name'].str.contains('immy'))]
# Out:
#     Name   Color  Number  Age
# 0  Timmy     red     100   25
# 1  Jimmy    blue      25   20
# 4   Fred  yellow      60   50
# 6    Ted    blue      55   40
# 7    Bob    none      80   39

# %% [markdown]
# ### Using Existing Columns to Make New Columns

# %%
df['Num_Age_Ratio'] = df['Number']/df['Age']

# %%
df
# Out:
#     Name   Color  Number  Age  Num_Age_Ratio
# 0  Timmy     red     100   25       4.000000
# 1  Jimmy    blue      25   20       1.250000
# 2     Ed   green      34   19       1.789474
# 3    Ned     red       7   31       0.225806
# 4   Fred  yellow      60   50       1.200000
# 5    Jed  orange       2   23       0.086957
# 6    Ted    blue      55   40       1.375000
# 7    Bob    none      80   39       2.051282

# %% [markdown]
# # Reading & Writing DataFrames

# %% [markdown]
# ## Reading CSVs

# %% [markdown]
# Suppose you have a CSV of the Harry Potter characters - how would you load it into python? f.open and readlines or some shit like that?
# NOOOOOOOOOOOOO
#
# use pandas!!

# %%
HP_chars_df = pd.read_csv('Data/Characters.csv')
HP_chars_df
# Out:
#      Character ID    Character Name                Species  Gender  \
# 0               1      Harry Potter                  Human    Male
# 1               2       Ron Weasley                  Human    Male
# 2               3  Hermione Granger                  Human  Female
# 3               4  Albus Dumbledore                  Human    Male
# 4               5     Rubeus Hagrid  Half-Human/Half-Giant    Male
# ..            ...               ...                    ...     ...
# 161           162            Waiter                    NaN     NaN
# 162           163             Boy 2                    NaN     NaN
# 163           164             Crowd                    NaN     NaN
# 164           165       Gryffindors                    NaN     NaN
# 165           166        Professors                    NaN     NaN
#
#           House              Patronus Wand (Wood)         Wand (Core)
# 0    Gryffindor                  Stag       Holly     Phoenix Feather
# 1    Gryffindor  Jack Russell Terrier         NaN                 NaN
# 2    Gryffindor                 Otter        Vine  Dragon Heartstring
# 3    Gryffindor               Phoenix       Elder  Thestral Tail Hair
# 4    Gryffindor                   NaN         Oak                 NaN
# ..          ...                   ...         ...                 ...
# 161         NaN                   NaN         NaN                 NaN
# 162         NaN                   NaN         NaN                 NaN
# 163         NaN                   NaN         NaN                 NaN
# 164         NaN                   NaN         NaN                 NaN
# 165         NaN                   NaN         NaN                 NaN
#
# [166 rows x 8 columns]

# %% [markdown]
# Using our knowledge gained from the previous section, let's make a more complex query to the DataFrame:
#
# Who are the Slytherins whose wand core contains Dragon Heartstring?

# %%
HP_chars_df[(HP_chars_df['House'] == 'Slytherin') & (HP_chars_df['Wand (Core)'] == 'Dragon Heartstring')]
# Out:
#     Character ID       Character Name Species  Gender      House Patronus  \
# 7              8      Horace Slughorn   Human    Male  Slytherin      NaN
# 14            15     Dolores Umbridge   Human  Female  Slytherin      Cat
# 21            22  Bellatrix Lestrange   Human  Female  Slytherin      NaN
# 22            23        Lucius Malfoy   Human    Male  Slytherin      NaN
#
#    Wand (Wood)         Wand (Core)
# 7        Cedar  Dragon Heartstring
# 14       Birch  Dragon Heartstring
# 21      Walnut  Dragon Heartstring
# 22         Elm  Dragon Heartstring

# %% [markdown]
# ## Reading CSVs With Different Header Settings
#
# What if we don't want to treat the first row as a header?

# %%
pd.read_csv('Data/Characters.csv', header = None)
# Out:
#                 0                 1        2       3           4  \
# 0    Character ID    Character Name  Species  Gender       House
# 1               1      Harry Potter    Human    Male  Gryffindor
# 2               2       Ron Weasley    Human    Male  Gryffindor
# 3               3  Hermione Granger    Human  Female  Gryffindor
# 4               4  Albus Dumbledore    Human    Male  Gryffindor
# ..            ...               ...      ...     ...         ...
# 162           162            Waiter      NaN     NaN         NaN
# 163           163             Boy 2      NaN     NaN         NaN
# 164           164             Crowd      NaN     NaN         NaN
# 165           165       Gryffindors      NaN     NaN         NaN
# 166           166        Professors      NaN     NaN         NaN
#
#                         5            6                   7
# 0                Patronus  Wand (Wood)         Wand (Core)
# 1                    Stag        Holly     Phoenix Feather
# 2    Jack Russell Terrier          NaN                 NaN
# 3                   Otter         Vine  Dragon Heartstring
# 4                 Phoenix        Elder  Thestral Tail Hair
# ..                    ...          ...                 ...
# 162                   NaN          NaN                 NaN
# 163                   NaN          NaN                 NaN
# 164                   NaN          NaN                 NaN
# 165                   NaN          NaN                 NaN
# 166                   NaN          NaN                 NaN
#
# [167 rows x 8 columns]

# %% [markdown]
# I want to skip the first five rows! No Problem!

# %%
pd.read_csv('Data/Characters.csv', skiprows=5)
# Out:
#        5       Rubeus Hagrid Half-Human/Half-Giant    Male  Gryffindor  \
# 0      6       Severus Snape                 Human    Male   Slytherin
# 1      7  Minerva McGonagall                 Human  Female  Gryffindor
# 2      8     Horace Slughorn                 Human    Male   Slytherin
# 3      9           Voldemort                 Human    Male   Slytherin
# 4     10  Neville Longbottom                 Human    Male  Gryffindor
# ..   ...                 ...                   ...     ...         ...
# 156  162              Waiter                   NaN     NaN         NaN
# 157  163               Boy 2                   NaN     NaN         NaN
# 158  164               Crowd                   NaN     NaN         NaN
# 159  165         Gryffindors                   NaN     NaN         NaN
# 160  166          Professors                   NaN     NaN         NaN
#
#     Unnamed: 5     Oak          Unnamed: 7
# 0          Doe     NaN                 NaN
# 1          Cat     Fir  Dragon Heartstring
# 2          NaN   Cedar  Dragon Heartstring
# 3          NaN     Yew     Phoenix Feather
# 4          NaN  Cherry        Unicorn Hair
# ..         ...     ...                 ...
# 156        NaN     NaN                 NaN
# 157        NaN     NaN                 NaN
# 158        NaN     NaN                 NaN
# 159        NaN     NaN                 NaN
# 160        NaN     NaN                 NaN
#
# [161 rows x 8 columns]

# %% [markdown]
# No no no... I don't want that as the header!

# %%
pd.read_csv('Data/Characters.csv', skiprows=5, header = None)
# Out:
#        0                   1                      2       3           4    5  \
# 0      5       Rubeus Hagrid  Half-Human/Half-Giant    Male  Gryffindor  NaN
# 1      6       Severus Snape                  Human    Male   Slytherin  Doe
# 2      7  Minerva McGonagall                  Human  Female  Gryffindor  Cat
# 3      8     Horace Slughorn                  Human    Male   Slytherin  NaN
# 4      9           Voldemort                  Human    Male   Slytherin  NaN
# ..   ...                 ...                    ...     ...         ...  ...
# 157  162              Waiter                    NaN     NaN         NaN  NaN
# 158  163               Boy 2                    NaN     NaN         NaN  NaN
# 159  164               Crowd                    NaN     NaN         NaN  NaN
# 160  165         Gryffindors                    NaN     NaN         NaN  NaN
# 161  166          Professors                    NaN     NaN         NaN  NaN
#
#          6                   7
# 0      Oak                 NaN
# 1      NaN                 NaN
# 2      Fir  Dragon Heartstring
# 3    Cedar  Dragon Heartstring
# 4      Yew     Phoenix Feather
# ..     ...                 ...
# 157    NaN                 NaN
# 158    NaN                 NaN
# 159    NaN                 NaN
# 160    NaN                 NaN
# 161    NaN                 NaN
#
# [162 rows x 8 columns]

# %% [markdown]
# ## Writing DataFrames

# %% [markdown]
# Suppose I want to find all the Gryffindors, then write the results to a local file.

# %%
gryf_df = HP_chars_df[HP_chars_df['House'] == 'Gryffindor']
gryf_df
# Out:
#      Character ID        Character Name                  Species  Gender  \
# 0               1          Harry Potter                    Human    Male
# 1               2           Ron Weasley                    Human    Male
# 2               3      Hermione Granger                    Human  Female
# 3               4      Albus Dumbledore                    Human    Male
# 4               5         Rubeus Hagrid    Half-Human/Half-Giant    Male
# 6               7    Minerva McGonagall                    Human  Female
# 9              10    Neville Longbottom                    Human    Male
# 10             11           Remus Lupin                 Werewolf    Male
# 13             14          Fred Weasley                    Human    Male
# 15             16        Arthur Weasley                    Human    Male
# 17             18          Sirius Black                    Human    Male
# 18             19        George Weasley                    Human    Male
# 19             20         Ginny Weasley                    Human  Female
# 25             26         Molly Weasley                    Human  Female
# 28             29       Seamus Finnigan                    Human    Male
# 36             37         Percy Weasley                    Human    Male
# 41             42          James Potter                    Human    Male
# 43             44       Peter Pettigrew                    Human    Male
# 44             45           Lily Potter                    Human  Female
# 45             46           Oliver Wood                    Human    Male
# 46             47  Nearly Headless Nick                    Ghost   Human
# 51             52            Lee Jordan                    Human    Male
# 64             65        Lavender Brown                    Human  Female
# 70             71       Cormac McLaggen                    Human    Male
# 72             73          Bill Weasley  Human (Werewolf Traits)    Male
# 73             74      Angelina Johnson                    Human  Female
# 74             75           Dean Thomas                    Human    Male
# 77             78         Parvati Patil                    Human  Female
# 93             94            Katie Bell                    Human  Female
# 105           106         Colin Creevey                    Human    Male
# 110           111         Nigel Wolpert                    Human    Male
#
#           House              Patronus Wand (Wood)         Wand (Core)
# 0    Gryffindor                  Stag       Holly     Phoenix Feather
# 1    Gryffindor  Jack Russell Terrier         NaN                 NaN
# 2    Gryffindor                 Otter        Vine  Dragon Heartstring
# 3    Gryffindor               Phoenix       Elder  Thestral Tail Hair
# 4    Gryffindor                   NaN         Oak                 NaN
# 6    Gryffindor                   Cat         Fir  Dragon Heartstring
# 9    Gryffindor                   NaN      Cherry        Unicorn Hair
# 10   Gryffindor                  Wolf     Cypress        Unicorn Hair
# 13   Gryffindor                   NaN         NaN                 NaN
# 15   Gryffindor                Weasel         NaN                 NaN
# 17   Gryffindor                   NaN         NaN                 NaN
# 18   Gryffindor                   NaN         NaN                 NaN
# 19   Gryffindor                 Horse         NaN                 NaN
# 25   Gryffindor                   NaN         NaN                 NaN
# 28   Gryffindor                   Fox         NaN                 NaN
# 36   Gryffindor                   NaN         NaN                 NaN
# 41   Gryffindor                  Stag    Mahogany                 NaN
# 43   Gryffindor                   NaN    Chestnut  Dragon Heartstring
# 44   Gryffindor                   Doe      Willow                 NaN
# 45   Gryffindor                   NaN         NaN                 NaN
# 46   Gryffindor                   NaN         NaN                 NaN
# 51   Gryffindor                   NaN         NaN                 NaN
# 64   Gryffindor                   NaN         NaN                 NaN
# 70   Gryffindor                   NaN         NaN                 NaN
# 72   Gryffindor                   NaN         NaN                 NaN
# 73   Gryffindor                   NaN         NaN                 NaN
# 74   Gryffindor                   NaN         NaN                 NaN
# 77   Gryffindor                   NaN         NaN                 NaN
# 93   Gryffindor                   NaN         NaN                 NaN
# 105  Gryffindor                   NaN         NaN                 NaN
# 110  Gryffindor                   NaN         NaN                 NaN

# %%
# This line writes the resulting dataframe to a .csv file, 
# while the index = False argument omits the index from the output.

gryf_df.to_csv('Gryffindor_Characters.csv',index = False)

# %%
gryf_df.to_dict() #converts dataframe to a dictionary object
# Out:
# {'Character ID': {0: 1,
#   1: 2,
#   2: 3,
#   3: 4,
#   4: 5,
#   6: 7,
#   9: 10,
#   10: 11,
#   13: 14,
#   15: 16,
#   17: 18,
#   18: 19,
#   19: 20,
#   25: 26,
#   28: 29,
#   36: 37,
#   41: 42,
#   43: 44,
#   44: 45,
#   45: 46,
#   46: 47,
#   51: 52,
#   64: 65,
#   70: 71,
#   72: 73,
#   73: 74,
#   74: 75,
#   77: 78,
#   93: 94,
#   105: 106,
#   110: 111},
#  'Character Name': {0: 'Harry Potter',
#   1: 'Ron Weasley',
#   2: 'Hermione Granger',
#   3: 'Albus Dumbledore',
#   4: 'Rubeus Hagrid',
#   6: 'Minerva McGonagall',
#   9: 'Neville Longbottom',
#   10: 'Remus Lupin',
#   13: 'Fred Weasley',
#   15: 'Arthur Weasley',
#   17: 'Sirius Black',
#   18: 'George Weasley',
#   19: 'Ginny Weasley',
#   25: 'Molly Weasley',
#   28: 'Seamus Finnigan',
#   36: 'Percy Weasley',
#   41: 'James Potter',
#   43: 'Peter Pettigrew',
#   44: 'Lily Potter',
#   45: 'Oliver Wood',
#   46: 'Nearly Headless Nick',
#   51: 'Lee Jordan',
#   64: 'Lavender Brown',
#   70: 'Cormac McLaggen',
#   72: 'Bill Weasley',
#   73: 'Angelina Johnson',
#   74: 'Dean Thomas',
#   77: 'Parvati Patil',
#   93: 'Katie Bell',
#   105: 'Colin Creevey',
#   110: 'Nigel Wolpert'},
#  'Species': {0: 'Human',
#   1: 'Human',
#   2: 'Human',
#   3: 'Human',
#   4: 'Half-Human/Half-Giant',
#   6: 'Human',
#   9: 'Human',
#   10: 'Werewolf',
#   13: 'Human',
#   15: 'Human',
#   17: 'Human',
#   18: 'Human',
#   19: 'Human',
#   25: 'Human',
#   28: 'Human',
#   36: 'Human',
#   41: 'Human',
#   43: 'Human',
#   44: 'Human',
#   45: 'Human',
#   46: 'Ghost',
#   51: 'Human',
#   64: 'Human',
#   70: 'Human',
#   72: 'Human (Werewolf Traits)',
#   73: 'Human',
#   74: 'Human',
#   77: 'Human',
#   93: 'Human',
#   105: 'Human',
#   110: 'Human'},
#  'Gender': {0: 'Male',
#   1: 'Male',
#   2: 'Female',
#   3: 'Male',
#   4: 'Male',
#   6: 'Female',
#   9: 'Male',
#   10: 'Male',
#   13: 'Male',
#   15: 'Male',
#   17: 'Male',
#   18: 'Male',
#   19: 'Female',
#   25: 'Female',
#   28: 'Male',
#   36: 'Male',
#   41: 'Male',
#   43: 'Male',
#   44: 'Female',
#   45: 'Male',
#   46: 'Human',
#   51: 'Male',
#   64: 'Female',
#   70: 'Male',
#   72: 'Male',
#   73: 'Female',
#   74: 'Male',
#   77: 'Female',
#   93: 'Female',
#   105: 'Male',
#   110: 'Male'},
#  'House': {0: 'Gryffindor',
#   1: 'Gryffindor',
#   2: 'Gryffindor',
#   3: 'Gryffindor',
#   4: 'Gryffindor',
#   6: 'Gryffindor',
#   9: 'Gryffindor',
#   10: 'Gryffindor',
#   13: 'Gryffindor',
#   15: 'Gryffindor',
#   17: 'Gryffindor',
#   18: 'Gryffindor',
#   19: 'Gryffindor',
#   25: 'Gryffindor',
#   28: 'Gryffindor',
#   36: 'Gryffindor',
#   41: 'Gryffindor',
#   43: 'Gryffindor',
#   44: 'Gryffindor',
#   45: 'Gryffindor',
#   46: 'Gryffindor',
#   51: 'Gryffindor',
#   64: 'Gryffindor',
#   70: 'Gryffindor',
#   72: 'Gryffindor',
#   73: 'Gryffindor',
#   74: 'Gryffindor',
#   77: 'Gryffindor',
#   93: 'Gryffindor',
#   105: 'Gryffindor',
#   110: 'Gryffindor'},
#  'Patronus': {0: 'Stag',
#   1: 'Jack Russell Terrier',
#   2: 'Otter',
#   3: 'Phoenix',
#   4: nan,
#   6: 'Cat',
#   9: nan,
#   10: 'Wolf',
#   13: nan,
#   15: 'Weasel',
#   17: nan,
#   18: nan,
#   19: 'Horse',
#   25: nan,
#   28: 'Fox',
#   36: nan,
#   41: 'Stag',
#   43: nan,
#   44: 'Doe',
#   45: nan,
#   46: nan,
#   51: nan,
#   64: nan,
#   70: nan,
#   72: nan,
#   73: nan,
#   74: nan,
#   77: nan,
#   93: nan,
#   105: nan,
#   110: nan},
#  'Wand (Wood)': {0: 'Holly',
#   1: nan,
#   2: 'Vine',
#   3: 'Elder',
#   4: 'Oak',
#   6: 'Fir',
#   9: 'Cherry',
#   10: 'Cypress',
#   13: nan,
#   15: nan,
#   17: nan,
#   18: nan,
#   19: nan,
#   25: nan,
#   28: nan,
#   36: nan,
#   41: 'Mahogany',
#   43: 'Chestnut',
#   44: 'Willow',
#   45: nan,
#   46: nan,
#   51: nan,
#   64: nan,
#   70: nan,
#   72: nan,
#   73: nan,
#   74: nan,
#   77: nan,
#   93: nan,
#   105: nan,
#   110: nan},
#  'Wand (Core)': {0: 'Phoenix Feather',
#   1: nan,
#   2: 'Dragon Heartstring',
#   3: 'Thestral Tail Hair',
#   4: nan,
#   6: 'Dragon Heartstring',
#   9: 'Unicorn Hair',
#   10: 'Unicorn Hair',
#   13: nan,
#   15: nan,
#   17: nan,
#   18: nan,
#   19: nan,
#   25: nan,
#   28: nan,
#   36: nan,
#   41: nan,
#   43: 'Dragon Heartstring',
#   44: nan,
#   45: nan,
#   46: nan,
#   51: nan,
#   64: nan,
#   70: nan,
#   72: nan,
#   73: nan,
#   74: nan,
#   77: nan,
#   93: nan,
#   105: nan,
#   110: nan}}

# %%
gryf_df.to_json('Gryffindor_Characters.json') #writes object to a .json object

# %% [markdown]
# # Aggregating Data Within a Series

# %% [markdown]
# ## .value_counts()

# %%
gryf_df['Gender'].value_counts()
# Out:
# Male      21
# Female     9
# Human      1
# Name: Gender, dtype: int64

# %%
gryf_df['Species'].value_counts()
# Out:
# Human                      27
# Half-Human/Half-Giant       1
# Werewolf                    1
# Ghost                       1
# Human (Werewolf Traits)     1
# Name: Species, dtype: int64

# %% [markdown]
# Going back to the original dataset, let's see how the houses break down

# %%
HP_chars_df['House'].value_counts(normalize = True) #expresses the unique values as proportions
# Out:
# Gryffindor                      0.413333
# Slytherin                       0.266667
# Ravenclaw                       0.160000
# Hufflepuff                      0.106667
# Beauxbatons Academy of Magic    0.026667
# Durmstrang Institute            0.026667
# Name: House, dtype: float64

# %%
HP_chars_df['House'].value_counts().plot.bar();

# %% [markdown]
# ## pd.cut()
#
# Suppose I want to divide the previous dataset into 3 bins. We can use the pd.cut function to do this.

# %%
house_counts = HP_chars_df['House'].value_counts()
house_counts
# Out:
# Gryffindor                      31
# Slytherin                       20
# Ravenclaw                       12
# Hufflepuff                       8
# Beauxbatons Academy of Magic     2
# Durmstrang Institute             2
# Name: House, dtype: int64

# %% [markdown]
# The default arguments will give you equally spaced bins.

# %%
pd.cut(house_counts,3)
# Out:
# Gryffindor                        (21.333, 31.0]
# Slytherin                       (11.667, 21.333]
# Ravenclaw                       (11.667, 21.333]
# Hufflepuff                       (1.971, 11.667]
# Beauxbatons Academy of Magic     (1.971, 11.667]
# Durmstrang Institute             (1.971, 11.667]
# Name: House, dtype: category
# Categories (3, interval[float64, right]): [(1.971, 11.667] < (11.667, 21.333] < (21.333, 31.0]]

# %% [markdown]
# If we want to use customized bin edges, we can do it like this:

# %%
pd.cut(house_counts,[1,7,18,99])
# Out:
# Gryffindor                      (18, 99]
# Slytherin                       (18, 99]
# Ravenclaw                        (7, 18]
# Hufflepuff                       (7, 18]
# Beauxbatons Academy of Magic      (1, 7]
# Durmstrang Institute              (1, 7]
# Name: House, dtype: category
# Categories (3, interval[int64, right]): [(1, 7] < (7, 18] < (18, 99]]

# %%
pd.cut(house_counts,[1,7,18,99], labels = ['Bottom Third', 'Middle Third', 'Top Third'])
# Out:
# Gryffindor                         Top Third
# Slytherin                          Top Third
# Ravenclaw                       Middle Third
# Hufflepuff                      Middle Third
# Beauxbatons Academy of Magic    Bottom Third
# Durmstrang Institute            Bottom Third
# Name: House, dtype: category
# Categories (3, object): ['Bottom Third' < 'Middle Third' < 'Top Third']

# %% [markdown]
# # Aggregating Data Within a DataFrame

# %% [markdown]
# For the next section, let's take a look at a dataset of 2000 individuals with the following data points: income, age, loan principal, default history (0 = False, 1 = True)

# %%
cred_df = pd.read_csv('Data/credit_data.csv')

# %%
cred_df
# Out:
#       clientid       income        age         loan  default
# 0            1  66155.92510  59.017015  8106.532131        0
# 1            2  34415.15397  48.117153  6564.745018        0
# 2            3  57317.17006  63.108049  8020.953296        0
# 3            4  42709.53420  45.751972  6103.642260        0
# 4            5  66952.68885  18.584336  8770.099235        1
# ...        ...          ...        ...          ...      ...
# 1995      1996  59221.04487  48.518179  1926.729397        0
# 1996      1997  69516.12757  23.162104  3503.176156        0
# 1997      1998  44311.44926  28.017167  5522.786693        1
# 1998      1999  43756.05660  63.971796  1622.722598        0
# 1999      2000  69436.57955  56.152617  7378.833599        0
#
# [2000 rows x 5 columns]

# %%
cred_df.describe()
# Out:
#           clientid        income          age          loan      default
# count  2000.000000   2000.000000  1997.000000   2000.000000  2000.000000
# mean   1000.500000  45331.600018    40.807559   4444.369695     0.141500
# std     577.494589  14326.327119    13.624469   3045.410024     0.348624
# min       1.000000  20014.489470   -52.423280      1.377630     0.000000
# 25%     500.750000  32796.459720    28.990415   1939.708847     0.000000
# 50%    1000.500000  45789.117310    41.317159   3974.719418     0.000000
# 75%    1500.250000  57791.281670    52.587040   6432.410625     0.000000
# max    2000.000000  69995.685580    63.971796  13766.051240     1.000000

# %%
cred_df = cred_df.dropna()
cred_df
# Out:
#       clientid       income        age         loan  default
# 0            1  66155.92510  59.017015  8106.532131        0
# 1            2  34415.15397  48.117153  6564.745018        0
# 2            3  57317.17006  63.108049  8020.953296        0
# 3            4  42709.53420  45.751972  6103.642260        0
# 4            5  66952.68885  18.584336  8770.099235        1
# ...        ...          ...        ...          ...      ...
# 1995      1996  59221.04487  48.518179  1926.729397        0
# 1996      1997  69516.12757  23.162104  3503.176156        0
# 1997      1998  44311.44926  28.017167  5522.786693        1
# 1998      1999  43756.05660  63.971796  1622.722598        0
# 1999      2000  69436.57955  56.152617  7378.833599        0
#
# [1997 rows x 5 columns]

# %%
cred_df = cred_df[cred_df['age'] > 0]
cred_df
# Out:
#       clientid       income        age         loan  default
# 0            1  66155.92510  59.017015  8106.532131        0
# 1            2  34415.15397  48.117153  6564.745018        0
# 2            3  57317.17006  63.108049  8020.953296        0
# 3            4  42709.53420  45.751972  6103.642260        0
# 4            5  66952.68885  18.584336  8770.099235        1
# ...        ...          ...        ...          ...      ...
# 1995      1996  59221.04487  48.518179  1926.729397        0
# 1996      1997  69516.12757  23.162104  3503.176156        0
# 1997      1998  44311.44926  28.017167  5522.786693        1
# 1998      1999  43756.05660  63.971796  1622.722598        0
# 1999      2000  69436.57955  56.152617  7378.833599        0
#
# [1994 rows x 5 columns]

# %% [markdown]
# ## .groupby()

# %%
cred_df[['income','age','loan','default']].groupby('default').mean()
# Out:
#                income        age         loan
# default
# 0        45315.073824  43.330354  3975.221437
# 1        45412.188607  26.401412  7272.856747

# %%
cred_df.default.value_counts()
# Out:
# 0    1711
# 1     283
# Name: default, dtype: int64

# %% [markdown]
# ## .crosstab()

# %%
conf_matrix = pd.crosstab(cred_df.age<40, cred_df.default)
conf_matrix
# Out:
# default     0    1
# age
# False    1050    0
# True      661  283

# %% [markdown]
# precision

# %%
conf_matrix.loc[True][1] / conf_matrix.loc[True].sum()
# Out:
# 0.2997881355932203

# %% [markdown]
# recall

# %%
conf_matrix.loc[True][1] / conf_matrix[1].sum()
# Out:
# 1.0

# %% [markdown]
# # Merging DataFrames

# %% [markdown]
# For the following section, let's create our own dataframes and look at the different ways to merge them.

# %% [markdown]
# ## How to Set/Reset DataFrame Index

# %%
grades_df = pd.DataFrame({'Name': ['Sal', 'Joe', 'Q', 'Murr'],'Grade': (100 * np.random.rand(4))})
grades_df
# Out:
#    Name      Grade
# 0   Sal  11.761803
# 1   Joe  63.843754
# 2     Q  94.267011
# 3  Murr   2.928479

# %%
majors_df = pd.DataFrame({'Name': ['Phil', 'Joe', 'Jack', 'Bob','Q'],'Major':['Applied Math','Computer Science','History','Civil Engineering','Philosophy']})
majors_df
# Out:
#    Name              Major
# 0  Phil       Applied Math
# 1   Joe   Computer Science
# 2  Jack            History
# 3   Bob  Civil Engineering
# 4     Q         Philosophy

# %%
grades_df = grades_df.set_index('Name')
grades_df
# Out:
#           Grade
# Name
# Sal   11.761803
# Joe   63.843754
# Q     94.267011
# Murr   2.928479

# %%
majors_df = majors_df.set_index('Name')
majors_df
# Out:
#                   Major
# Name
# Phil       Applied Math
# Joe    Computer Science
# Jack            History
# Bob   Civil Engineering
# Q            Philosophy

# %%
majors_df.reset_index() #If you want to undo the new index, you can reset it like so.
# Out:
#    Name              Major
# 0  Phil       Applied Math
# 1   Joe   Computer Science
# 2  Jack            History
# 3   Bob  Civil Engineering
# 4     Q         Philosophy

# %% [markdown]
# ## Outer/Inner Joins

# %%
grades_df.merge(majors_df,how = 'inner',on = 'Name') #intersection of two dataframes
# Out:
#           Grade             Major
# Name
# Joe   63.843754  Computer Science
# Q     94.267011        Philosophy

# %%
grades_df.merge(majors_df,how = 'outer',on = 'Name') #union of two dataframes
# Out:
#           Grade              Major
# Name
# Sal   11.761803                NaN
# Joe   63.843754   Computer Science
# Q     94.267011         Philosophy
# Murr   2.928479                NaN
# Phil        NaN       Applied Math
# Jack        NaN            History
# Bob         NaN  Civil Engineering

# %% [markdown]
# ## Left/Right Merges

# %% [markdown]
# Once we learn how to merge dataframes, we can take multiple tables of information and combine them to answer more sophisticated questions:
# (Under the implied assumption that the data is accurate)
# * Approximately how much of the Harry Potter Cinematic Universe (HPCU) takes place in Hogwarts?
#     * What are the 5 most common locations within the HPCU ?
# * In how many lines is the word 'Horcruxes' mentioned?

# %%
HP_places_df = pd.read_csv('Data/Places.csv')
HP_dialogue_df = pd.read_csv('Data/Dialogue.csv', encoding = "ISO-8859-1")

# %%
HP_merged_df = HP_dialogue_df.merge(HP_places_df,how = 'left', on='Place ID')
HP_merged_df.sort_values('Dialogue ID')
# Out:
#       Dialogue ID  Chapter ID  Place ID  Character ID  \
# 0               1           1         8             4
# 1               2           1         8             7
# 2               3           1         8             4
# 3               4           1         8             7
# 4               5           1         8             4
# ...           ...         ...       ...           ...
# 7439         7440         234        71             1
# 7440         7441         234        71            84
# 7441         7442         234        71             1
# 7442         7443         234        71             1
# 7443         7444         234        71            84
#
#                                                Dialogue  \
# 0     I should have known that you would be here...P...
# 1     Good evening, Professor Dumbledore. Are the ru...
# 2      I'm afraid so, Professor. The good, and the bad.
# 3                                          And the boy?
# 4                               Hagrid is bringing him.
# ...                                                 ...
# 7439  Then Slytherin House will have gained a wonder...
# 7440                                            Really?
# 7441                                            Really.
# 7442                                             Ready?
# 7443                                             Ready.
#
#                             Place Name           Place Category
# 0                       4 Privet Drive                Dwellings
# 1                       4 Privet Drive                Dwellings
# 2                       4 Privet Drive                Dwellings
# 3                       4 Privet Drive                Dwellings
# 4                       4 Privet Drive                Dwellings
# ...                                ...                      ...
# 7439  Platform Nine and Three-Quarters  Other Magical Locations
# 7440  Platform Nine and Three-Quarters  Other Magical Locations
# 7441  Platform Nine and Three-Quarters  Other Magical Locations
# 7442  Platform Nine and Three-Quarters  Other Magical Locations
# 7443  Platform Nine and Three-Quarters  Other Magical Locations
#
# [7444 rows x 7 columns]

# %%
HP_merged_df
# Out:
#       Dialogue ID  Chapter ID  Place ID  Character ID  \
# 0               1           1         8             4
# 1               2           1         8             7
# 2               3           1         8             4
# 3               4           1         8             7
# 4               5           1         8             4
# ...           ...         ...       ...           ...
# 7439         7440         234        71             1
# 7440         7441         234        71            84
# 7441         7442         234        71             1
# 7442         7443         234        71             1
# 7443         7444         234        71            84
#
#                                                Dialogue  \
# 0     I should have known that you would be here...P...
# 1     Good evening, Professor Dumbledore. Are the ru...
# 2      I'm afraid so, Professor. The good, and the bad.
# 3                                          And the boy?
# 4                               Hagrid is bringing him.
# ...                                                 ...
# 7439  Then Slytherin House will have gained a wonder...
# 7440                                            Really?
# 7441                                            Really.
# 7442                                             Ready?
# 7443                                             Ready.
#
#                             Place Name           Place Category
# 0                       4 Privet Drive                Dwellings
# 1                       4 Privet Drive                Dwellings
# 2                       4 Privet Drive                Dwellings
# 3                       4 Privet Drive                Dwellings
# 4                       4 Privet Drive                Dwellings
# ...                                ...                      ...
# 7439  Platform Nine and Three-Quarters  Other Magical Locations
# 7440  Platform Nine and Three-Quarters  Other Magical Locations
# 7441  Platform Nine and Three-Quarters  Other Magical Locations
# 7442  Platform Nine and Three-Quarters  Other Magical Locations
# 7443  Platform Nine and Three-Quarters  Other Magical Locations
#
# [7444 rows x 7 columns]

# %%
HP_merged_df.merge(HP_chars_df,how = 'left', on='Character ID').sort_values('Dialogue ID')
# Out:
#       Dialogue ID  Chapter ID  Place ID  Character ID  \
# 0               1           1         8             4
# 1               2           1         8             7
# 2               3           1         8             4
# 3               4           1         8             7
# 4               5           1         8             4
# ...           ...         ...       ...           ...
# 7439         7440         234        71             1
# 7440         7441         234        71            84
# 7441         7442         234        71             1
# 7442         7443         234        71             1
# 7443         7444         234        71            84
#
#                                                Dialogue  \
# 0     I should have known that you would be here...P...
# 1     Good evening, Professor Dumbledore. Are the ru...
# 2      I'm afraid so, Professor. The good, and the bad.
# 3                                          And the boy?
# 4                               Hagrid is bringing him.
# ...                                                 ...
# 7439  Then Slytherin House will have gained a wonder...
# 7440                                            Really?
# 7441                                            Really.
# 7442                                             Ready?
# 7443                                             Ready.
#
#                             Place Name           Place Category  \
# 0                       4 Privet Drive                Dwellings
# 1                       4 Privet Drive                Dwellings
# 2                       4 Privet Drive                Dwellings
# 3                       4 Privet Drive                Dwellings
# 4                       4 Privet Drive                Dwellings
# ...                                ...                      ...
# 7439  Platform Nine and Three-Quarters  Other Magical Locations
# 7440  Platform Nine and Three-Quarters  Other Magical Locations
# 7441  Platform Nine and Three-Quarters  Other Magical Locations
# 7442  Platform Nine and Three-Quarters  Other Magical Locations
# 7443  Platform Nine and Three-Quarters  Other Magical Locations
#
#           Character Name Species  Gender       House Patronus Wand (Wood)  \
# 0       Albus Dumbledore   Human    Male  Gryffindor  Phoenix       Elder
# 1     Minerva McGonagall   Human  Female  Gryffindor      Cat         Fir
# 2       Albus Dumbledore   Human    Male  Gryffindor  Phoenix       Elder
# 3     Minerva McGonagall   Human  Female  Gryffindor      Cat         Fir
# 4       Albus Dumbledore   Human    Male  Gryffindor  Phoenix       Elder
# ...                  ...     ...     ...         ...      ...         ...
# 7439        Harry Potter   Human    Male  Gryffindor     Stag       Holly
# 7440        Albus Potter   Human    Male   Slytherin      NaN         NaN
# 7441        Harry Potter   Human    Male  Gryffindor     Stag       Holly
# 7442        Harry Potter   Human    Male  Gryffindor     Stag       Holly
# 7443        Albus Potter   Human    Male   Slytherin      NaN         NaN
#
#              Wand (Core)
# 0     Thestral Tail Hair
# 1     Dragon Heartstring
# 2     Thestral Tail Hair
# 3     Dragon Heartstring
# 4     Thestral Tail Hair
# ...                  ...
# 7439     Phoenix Feather
# 7440                 NaN
# 7441     Phoenix Feather
# 7442     Phoenix Feather
# 7443                 NaN
#
# [7444 rows x 14 columns]

# %%
HP_merged_df = HP_merged_df.merge(HP_chars_df,how = 'right', on='Character ID')

# %%
HP_condensed_df = HP_merged_df[['Dialogue ID','Character Name','Place Name', 'Place Category','Dialogue']].set_index('Dialogue ID')

# %%
HP_condensed_df = HP_condensed_df.sort_index()

# %%
HP_condensed_df
# Out:
#                  Character Name                        Place Name  \
# Dialogue ID
# 1              Albus Dumbledore                    4 Privet Drive
# 2            Minerva McGonagall                    4 Privet Drive
# 3              Albus Dumbledore                    4 Privet Drive
# 4            Minerva McGonagall                    4 Privet Drive
# 5              Albus Dumbledore                    4 Privet Drive
# ...                         ...                               ...
# 7440               Harry Potter  Platform Nine and Three-Quarters
# 7441               Albus Potter  Platform Nine and Three-Quarters
# 7442               Harry Potter  Platform Nine and Three-Quarters
# 7443               Harry Potter  Platform Nine and Three-Quarters
# 7444               Albus Potter  Platform Nine and Three-Quarters
#
#                       Place Category  \
# Dialogue ID
# 1                          Dwellings
# 2                          Dwellings
# 3                          Dwellings
# 4                          Dwellings
# 5                          Dwellings
# ...                              ...
# 7440         Other Magical Locations
# 7441         Other Magical Locations
# 7442         Other Magical Locations
# 7443         Other Magical Locations
# 7444         Other Magical Locations
#
#                                                       Dialogue
# Dialogue ID
# 1            I should have known that you would be here...P...
# 2            Good evening, Professor Dumbledore. Are the ru...
# 3             I'm afraid so, Professor. The good, and the bad.
# 4                                                 And the boy?
# 5                                      Hagrid is bringing him.
# ...                                                        ...
# 7440         Then Slytherin House will have gained a wonder...
# 7441                                                   Really?
# 7442                                                   Really.
# 7443                                                    Ready?
# 7444                                                    Ready.
#
# [7444 rows x 4 columns]

# %%
HP_condensed_df.value_counts('Place Category',normalize = True)
# Out:
# Place Category
# Hogwarts                   0.605051
# Dwellings                  0.189146
# Other Magical Locations    0.128023
# Diagon Alley               0.040838
# Hogsmeade                  0.036943
# dtype: float64

# %%
HP_condensed_df.value_counts('Place Name').iloc[:5]
# Out:
# Place Name
# Great Hall                557
# 4 Privet Drive            347
# Griffindor Common Room    343
# Ministry of Magic         327
# Hagrid's Hut              313
# dtype: int64

# %%
HP_condensed_df[HP_condensed_df['Dialogue'].str.contains('Horcruxes')]
# Out:
#                    Character Name          Place Name  \
# Dialogue ID
# 5712             Hermione Granger     Astronomy Tower
# 5904                 Harry Potter          The Burrow
# 5907                  Ron Weasley          The Burrow
# 5908                  Ron Weasley          The Burrow
# 6059             Hermione Granger  12 Grimmauld Place
# 6232                 Harry Potter             Unknown
# 6255                  Ron Weasley             Unknown
# 6319                 Harry Potter             Unknown
# 6922                 Harry Potter             Unknown
# 6933                  Ron Weasley             Unknown
# 6959                 Harry Potter      The Hog's Head
# 6968         Aberforth Dumbledore      The Hog's Head
# 7284                 Harry Potter       Entrance Hall
#
#                       Place Category  \
# Dialogue ID
# 5712                        Hogwarts
# 5904                       Dwellings
# 5907                       Dwellings
# 5908                       Dwellings
# 6059                       Dwellings
# 6232         Other Magical Locations
# 6255         Other Magical Locations
# 6319         Other Magical Locations
# 6922         Other Magical Locations
# 6933         Other Magical Locations
# 6959                       Hogsmeade
# 6968                       Hogsmeade
# 7284                        Hogwarts
#
#                                                       Dialogue
# Dialogue ID
# 5712         You don't honestly think you can find all thos...
# 5904         I don't care about a bloody wedding -- no matt...
# 5907         I mean, they're bits of his soul, the Horcruxe...
# 5908         What I'm saying is, if we do this thing right,...
# 6059         Harry.  I can imagine why you'd want to go the...
# 6232         Dumbledore had a theory.  He felt that the Hor...
# 6255         Seems strange, mate.  Dumbledore sends you off...
# 6319                             ... it can destroy Horcruxes.
# 6922         He's angry. But he's scared too. He's going to...
# 6933         Maybe it's because of the Horcruxes. Maybe he'...
# 6959         We've been hunting Horcruxes. We think the las...
# 6968         That's a boy's answer. A boy who goes chasing ...
# 7284         There's a reason I can... hear them -- the Hor...

# %%
HP_condensed_df[HP_condensed_df['Dialogue'].str.contains('Horcruxes')].shape[0]
# Out:
# 13

# %% [markdown]
# # Data Visualization Within A DataFrame

# %%
income_df = pd.read_csv('Data/median_weekly_earnings_1979to2018.csv')
income_df.head(5)
# Out:
#      Year  Median Weekly Earnings
# 0  1979.0                    332.0
# 1  1980.0                    318.0
# 2  1981.0                    312.0
# 3  1982.0                    313.0
# 4  1983.0                    314.0

# %%
income_df = income_df.dropna().astype(int)
income_df.head(5)
# Out:
#    Year  Median Weekly Earnings
# 0  1979                      332
# 1  1980                      318
# 2  1981                      312
# 3  1982                      313
# 4  1983                      314

# %%
income_df.plot.scatter('Year','Median Weekly Earnings ',marker = '^',color = 'r');

# %%
income_df.plot.line('Year','Median Weekly Earnings ',marker = 's',color = 'g');

# %%
income_df.plot.line('Year','Median Weekly Earnings ',marker = 's',color = 'g', title = 'Year vs. Median Weekly Earnings');

# %%
income_df.plot.line('Year','Median Weekly Earnings ',marker = 's',color = 'g', title = 'Year vs. Median Weekly Earnings', ylabel = 'Dollars');

# %%
income_df['Median Weekly Earnings '].plot.box(title = 'Title', color = 'red');
